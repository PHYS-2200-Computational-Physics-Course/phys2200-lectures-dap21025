# %%
using DelimitedFiles
using PyPlot

# %%
url = "https://www.phys.uconn.edu/~rozman/Courses/P2200_25F/downloads/trinity-test.data"
# Out:
# "https://www.phys.uconn.edu/~rozman/Courses/P2200_25F/downloads/trinity-test.data"

# %%
obsevations = download(url)
# Out:
# "/tmp/jl_yPAxM5cZk5"

# %%
dat = readdlm(obsevations, comments=true, comment_char='#')
# Out:
# 25×2 Matrix{Float64}:
#   0.1    11.1
#   0.24   19.9
#   0.38   25.4
#   0.52   28.8
#   0.66   31.9
#   0.8    34.2
#   0.94   36.3
#   1.08   38.9
#   1.22   41.0
#   1.36   42.8
#   1.5    44.4
#   1.65   46.0
#   1.79   46.9
#   1.93   48.7
#   3.26   59.0
#   3.53   61.1
#   3.8    62.9
#   4.07   64.3
#   4.34   65.6
#   4.61   67.3
#  15.0   106.5
#  25.0   130.0
#  34.0   145.0
#  53.0   175.0
#  62.0   185.0

# %%
t = dat[:,1]
# Out:
# 25-element Vector{Float64}:
#   0.1
#   0.24
#   0.38
#   0.52
#   0.66
#   0.8
#   0.94
#   1.08
#   1.22
#   1.36
#   1.5
#   1.65
#   1.79
#   1.93
#   3.26
#   3.53
#   3.8
#   4.07
#   4.34
#   4.61
#  15.0
#  25.0
#  34.0
#  53.0
#  62.0

# %%
radius = dat[:,2]
# Out:
# 25-element Vector{Float64}:
#   11.1
#   19.9
#   25.4
#   28.8
#   31.9
#   34.2
#   36.3
#   38.9
#   41.0
#   42.8
#   44.4
#   46.0
#   46.9
#   48.7
#   59.0
#   61.1
#   62.9
#   64.3
#   65.6
#   67.3
#  106.5
#  130.0
#  145.0
#  175.0
#  185.0

# %%
plot(t, radius);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
loglog(t, radius, "bo")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7dc5fa15f320>

# %%
loglog(t, radius, "ro", label="measurements")
grid(true)
xlabel("time (seconds)")
ylabel("radius (meters)")
title("Trinity Test Data (Observational)")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7dc5f96f5d60>

# %%
const beta = 2/5
rad(t,alpha) = alpha * t^beta ;
nexcl = 2
np = length(t)
ind = (nexcl+1):np
# Out:
# 3:25

# %%
tlogbar = sum(log.(t[ind])) / length(ind)
rlogbar = sum(log.(radius[ind])) / length(ind)
alphalog = rlogbar - beta * tlogbar
alpha = exp(alphalog)
println("α = $(round(alpha, sigdigits=4))")
# Out:
# α = 36.92

# %%
loglog(t, radius, "ro", label="Measurements")
loglog(t, rad.(t, alpha), "g", "-", label="Line of Best Fit")

grid(true)
xlabel("time (ms)")
ylabel("radius as a function of time (m)")
title("Trinity fireball radius as a function of time")
legend();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
